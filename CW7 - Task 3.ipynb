# %% [markdown]
# # CW7 - Statistical Thermodynamics
# ## Problem Set 3
# ### Aadil Aslam

# %%
from random import seed
from random import randint
import random
import numpy as np
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ## Question 1

# %% [markdown]
# #### 1.) Define constants and parameters:
#
#     #p[]>:1=susceptible, 0= Immunised, 2 = Infected
#     seed=randomize()                                      # start random numbers
#     nums=1000                                             # number of students
#     fract=0.01                                            # fract initially immune
#     recovr= 0.2                                           # chance recovering / day
#     num_infect=1                                          # number infected/day
#     numd=40                                               # number of days
#     reps=40                                               # number of repeats
#     data= Array(1..numd)                                  # array for infected
#     sdata= Array(1..numd)                                 # array of susceptibles
#     array P:0=immune, 1=susceptible, 2=infected
#     remov=0                                               # number removed

# %% [markdown]
# #### 2.) Make one for..do loop over the number of repeat calculations.
#
# for k from 1 to reps do                                       # loop for repeat calc'n<br>
#      P=Array(1..nums)                                         # student array to zero<br>
#      for i from 1 to nums do                                  # choose susceptibles<br>
#      P[i]=1                                                   # all susceptible<br>
#      end do
#
#
#
# #### 3. ) Choose at random those to be immune and one (also at random) to be infected initially.
#
#  fn=trunc(fract*nums)                                       # make into integer<br>
#  n=0<br>
#  while n < fn do                                            # exact fract*nums immune<br>
#      rr=rand(1..nums)<br>
#      ra=rr()<br>
#          if P[ra] <> 0 then<br>
#          P[ra]=0<br>
#          n=n+1<br>
#  end if<br>
#  end do<br>
#
#  n=0
#  while n < 1 do                                             # 1 infected not one of immune<br>
#      rr= rand(1..nums)
#      ra= rr()<br>
#      if P[ra]=1 then<br>
#          P[ra]=2<br>
#          n=1<br>
#  end if<br>
#  end do<br>
#
# #### Inside this make a second for..do loop to range over the number of days.
#
# for j from 1 to numd do
#
#
# #### Make a third for..do loop to range over the number of students.
#
# for i from 1 to nums do
#
# #### If infected students is found, choose one more at random and infect if not immune. This is the step S->I and depends on both S and I and the rate constant k2 of 1/day.
#
# if P[i] = 2 then<br>
#     for ii from 1 to num_infect do<br>
#          ra=rr()<br>
#          if P[ra]=1 then<br>
#          P[ra]=2<br>
#          remov=remov+1<br>
#  end if<br>
#  end do<br>
#  end if<br>
#
# ####  Choose a random number in the range 0 to 1, and if less than the chance of recovery, Choose a student at random and if already infected, make immune. This is the removal step with rate constant 0.2/day, and depends only on those infected.
#
# if rand()/1e12 < recovr then<br>
#     ra=rr()<br>
#     if P[ra] = 2 then P[ra]=0<br>
#     end if<br>
# end if
#
# #### End the loop over the number of students.
#
#  end do # end loop i
#
#
# #### 4.) Add up the number of students infected and store result
#
# c=0: s=0<br>
#  for i from 1 to nums do # find number infected<br>
#  if P[i]=2 then c=c+1 end if<br>
#  if P[i]=1 then s=s+1 end if<br>
#  end do<br>
#  data[j]=data[j]+c # number infected<br>
#  sdata[j]=sdata[j]+s # number suscept<br>
#
#
# #### 5.) End the repeat loop
#
# end do # end loop j days<br>
# end do # end loop repeats<br>
# num_infected=remov*1.0/reps # total number of students infected in 40 days<br>

# %% [markdown]
# ## Question 2

# %%
nums=1000     
fract=0.01   
recovr= 0.2         
num_infect=1      
numd=40                                
reps=40                             
data= np.arange(numd)               
sdata= np.arange(numd)  
remov=0                                

for k in range (reps):     
    P=np.arange(nums)                 
    for i in range (nums):                
        P[i]=1                                
    fn=np.trunc(fract*nums)               
    n=0
    while n < fn:                       
        ra=np.random.randint(nums)
        if P[ra] != 0:
            P[ra]=0
            n=n+1
    n=0
    while n < 1:                        
        ra = np.random.randint(nums)
        if P[ra]==1:
            P[ra]=2
            n=1

    for j in range (numd):               
        for i in range (nums):             
            if P[i] == 2:                      
                for ii in range (num_infect):
                    ra=np.random.randint(nums)
                    if P[ra] == 1:
                        P[ra] = 2
                        remov=remov+1                         
            if np.random.rand()< recovr: 
                ra=np.random.randint(nums)
                if P[ra] == 2:
                    P[ra]=0 
        c=0
        s=0
        for i in range (nums):               
            if P[i] == 2:
                c=c+1
            if P[i] == 1:
                s=s+1
        data[j]=data[j]+c                   
        sdata[j]=sdata[j]+s                   

num_infected=remov*1.0/reps
print("Average number of students infected =",num_infected)

x=np.arange(numd)
y1=sdata/reps # Number of Susceptible Students
y2=data/reps # Number of Infected Students 
y3=nums-fn-(sdata/numd) # Number of Affected Students
plt.plot(x,y1,'g',x,y2,'r',x,y3,'k')
plt.xlim(0,40)
plt.ylim(0,1000)
plt.title("A plot showing the spread of infection over 40 days")
plt.xlabel("Number of days")
plt.ylabel("Number of students")
plt.legend(['Susceptible','Infected','Affected'])
plt.show()
# Out:
# Average number of students infected = 858.825

# %% [markdown]
# This is unlikely to work in real life. This assumes that when a susceptible student comes into contact with an infected student they then become infected. In real life, vaccines and other measures to prevent disease exist which this model doesn't take into account.

# %% [markdown]
# ## Question 3

# %%
# Change the fraction of immunised students 

nums=1000     
fract=0.003   
recovr= 0.2         
num_infect=1      
numd=40                                
reps=40                             
data= np.arange(numd)               
sdata= np.arange(numd)  
remov=0                                

for k in range (reps):     
    P=np.arange(nums)                 
    for i in range (nums):                
        P[i]=1                                
    fn=np.trunc(fract*nums)               
    n=0
    while n < fn:                       
        ra=np.random.randint(nums)
        if P[ra] != 0:
            P[ra]=0
            n=n+1
    n=0
    while n < 1:                        
        ra = np.random.randint(nums)
        if P[ra]==1:
            P[ra]=2
            n=1

    for j in range (numd):               
        for i in range (nums):             
            if P[i] == 2:                      
                for ii in range (num_infect):
                    ra=np.random.randint(nums)
                    if P[ra] == 1:
                        P[ra] = 2
                        remov=remov+1                         
            if np.random.rand()< recovr: 
                ra=np.random.randint(nums)
                if P[ra] == 2:
                    P[ra]=0 
        c=0
        s=0
        for i in range (nums):               
            if P[i] == 2:
                c=c+1
            if P[i] == 1:
                s=s+1
        data[j]=data[j]+c                   
        sdata[j]=sdata[j]+s                   

num_infected=remov*1.0/reps
print("Average number of students infected =",num_infected)

x=np.arange(numd)
y1=sdata/reps # Number of Susceptible Students
y2=data/reps # Number of Infected Students 
y3=nums-fn-(sdata/numd) # Number of Affected Students
plt.plot(x,y1,'g',x,y2,'r',x,y3,'k')
plt.title("A plot showing the spread of infection over \n 40 days when the fraction of immunised students is 0.003")
plt.xlabel("Number of days")
plt.ylabel("Number of students")
plt.xlim(0,40)
plt.ylim(0,1000)
plt.legend(['Susceptible','Infected','Affected'])
plt.show()

nums=1000     
fract=0.03   
recovr= 0.2         
num_infect=1      
numd=40                                
reps=40                             
data= np.arange(numd)               
sdata= np.arange(numd)  
remov=0                                

for k in range (reps):     
    P=np.arange(nums)                 
    for i in range (nums):                
        P[i]=1                                
    fn=np.trunc(fract*nums)               
    n=0
    while n < fn:                       
        ra=np.random.randint(nums)
        if P[ra] != 0:
            P[ra]=0
            n=n+1
    n=0
    while n < 1:                        
        ra = np.random.randint(nums)
        if P[ra]==1:
            P[ra]=2
            n=1

    for j in range (numd):               
        for i in range (nums):             
            if P[i] == 2:                      
                for ii in range (num_infect):
                    ra=np.random.randint(nums)
                    if P[ra] == 1:
                        P[ra] = 2
                        remov=remov+1                         
            if np.random.rand()< recovr: 
                ra=np.random.randint(nums)
                if P[ra] == 2:
                    P[ra]=0 
        c=0
        s=0
        for i in range (nums):               
            if P[i] == 2:
                c=c+1
            if P[i] == 1:
                s=s+1
        data[j]=data[j]+c                   
        sdata[j]=sdata[j]+s                   

num_infected=remov*1.0/reps
print("Average number of students infected =",num_infected)

x=np.arange(numd)
y1=sdata/reps # Number of Susceptible Students
y2=data/reps # Number of Infected Students 
y3=nums-fn-(sdata/numd) # Number of Affected Students
plt.plot(x,y1,'g',x,y2,'r',x,y3,'k')
plt.title("A plot showing the spread of infection over \n 40 days when the fraction of immunised students is 0.03")
plt.xlabel("Number of days")
plt.ylabel("Number of students")
plt.xlim(0,40)
plt.ylim(0,1000)
plt.legend(['Susceptible','Infected','Affected'])
plt.show()

nums=1000     
fract=0.3   
recovr= 0.2         
num_infect=1      
numd=40                                
reps=40                             
data= np.arange(numd)               
sdata= np.arange(numd)  
remov=0                                

for k in range (reps):     
    P=np.arange(nums)                 
    for i in range (nums):                
        P[i]=1                                
    fn=np.trunc(fract*nums)               
    n=0
    while n < fn:                       
        ra=np.random.randint(nums)
        if P[ra] != 0:
            P[ra]=0
            n=n+1
    n=0
    while n < 1:                        
        ra = np.random.randint(nums)
        if P[ra]==1:
            P[ra]=2
            n=1

    for j in range (numd):               
        for i in range (nums):             
            if P[i] == 2:                      
                for ii in range (num_infect):
                    ra=np.random.randint(nums)
                    if P[ra] == 1:
                        P[ra] = 2
                        remov=remov+1                         
            if np.random.rand()< recovr: 
                ra=np.random.randint(nums)
                if P[ra] == 2:
                    P[ra]=0 
        c=0
        s=0
        for i in range (nums):               
            if P[i] == 2:
                c=c+1
            if P[i] == 1:
                s=s+1
        data[j]=data[j]+c                   
        sdata[j]=sdata[j]+s                   

num_infected=remov*1.0/reps
print("Average number of students infected =",num_infected)

x=np.arange(numd)
y1=sdata/reps # Number of Susceptible Students
y2=data/reps # Number of Infected Students 
y3=nums-fn-(sdata/numd) # Number of Affected Students 
plt.plot(x,y1,'g',x,y2,'r',x,y3,'k')
plt.title("A plot showing the spread of infection over \n 40 days when the fraction of immunised students is 0.3")
plt.xlabel("Number of days")
plt.ylabel("Number of students")
plt.xlim(0,40)
plt.ylim(0,1000)
plt.legend(['Susceptible','Infected','Affected'])
plt.show()
# Out:
# Average number of students infected = 915.575
# Average number of students infected = 817.05
# Average number of students infected = 589.05

# %%
# Change the fraction of recovery

nums=1000     
fract=0.01   
recovr= 0.17         
num_infect=1      
numd=40                                
reps=40                             
data= np.arange(numd)               
sdata= np.arange(numd)  
remov=0                                

for k in range (reps):     
    P=np.arange(nums)                 
    for i in range (nums):                
        P[i]=1                                
    fn=np.trunc(fract*nums)               
    n=0
    while n < fn:                       
        ra=np.random.randint(nums)
        if P[ra] != 0:
            P[ra]=0
            n=n+1
    n=0
    while n < 1:                        
        ra = np.random.randint(nums)
        if P[ra]==1:
            P[ra]=2
            n=1

    for j in range (numd):               
        for i in range (nums):             
            if P[i] == 2:                      
                for ii in range (num_infect):
                    ra=np.random.randint(nums)
                    if P[ra] == 1:
                        P[ra] = 2
                        remov=remov+1                         
            if np.random.rand()< recovr: 
                ra=np.random.randint(nums)
                if P[ra] == 2:
                    P[ra]=0 
        c=0
        s=0
        for i in range (nums):               
            if P[i] == 2:
                c=c+1
            if P[i] == 1:
                s=s+1
        data[j]=data[j]+c                   
        sdata[j]=sdata[j]+s                   

num_infected=remov*1.0/reps
print("Average number of students infected =",num_infected)

x=np.arange(numd)
y1=sdata/reps # Number of Susceptible Students
y2=data/reps # Number of Infected Students 
y3=nums-fn-(sdata/numd) # Number of Affected Students
plt.plot(x,y1,'g',x,y2,'r',x,y3,'k')
plt.title(" A plot showing the spread of infection over \n 40 days when the fraction of recovery is 0.17")
plt.xlabel("Number of days")
plt.ylabel("Number of students")
plt.xlim(0,40)
plt.ylim(0,1000)
plt.legend(['Susceptible','Infected','Affected'])
plt.show()

nums=1000     
fract=0.01   
recovr= 0.34         
num_infect=1      
numd=40                                
reps=40                             
data= np.arange(numd)               
sdata= np.arange(numd)  
remov=0                                

for k in range (reps):     
    P=np.arange(nums)                 
    for i in range (nums):                
        P[i]=1                                
    fn=np.trunc(fract*nums)               
    n=0
    while n < fn:                       
        ra=np.random.randint(nums)
        if P[ra] != 0:
            P[ra]=0
            n=n+1
    n=0
    while n < 1:                        
        ra = np.random.randint(nums)
        if P[ra]==1:
            P[ra]=2
            n=1

    for j in range (numd):               
        for i in range (nums):             
            if P[i] == 2:                      
                for ii in range (num_infect):
                    ra=np.random.randint(nums)
                    if P[ra] == 1:
                        P[ra] = 2
                        remov=remov+1                         
            if np.random.rand()< recovr: 
                ra=np.random.randint(nums)
                if P[ra] == 2:
                    P[ra]=0 
        c=0
        s=0
        for i in range (nums):               
            if P[i] == 2:
                c=c+1
            if P[i] == 1:
                s=s+1
        data[j]=data[j]+c                   
        sdata[j]=sdata[j]+s                   

num_infected=remov*1.0/reps
print("Average number of students infected =",num_infected)

x=np.arange(numd)
y1=sdata/reps # Number of Susceptible Students
y2=data/reps # Number of Infected Students  
y3=nums-fn-(sdata/numd) # Number of Affected Students
plt.plot(x,y1,'g',x,y2,'r',x,y3,'k')
plt.title("A plot showing the spread of infection over \n 40 days when the fraction of recovery is 0.34")
plt.xlabel("Number of days")
plt.ylabel("Number of students")
plt.xlim(0,40)
plt.ylim(0,1000)
plt.legend(['Susceptible','Infected','Affected'])
plt.show()


nums=1000     
fract=0.01   
recovr= 0.51         
num_infect=1      
numd=40                                
reps=40                             
data= np.arange(numd)               
sdata= np.arange(numd)  
remov=0                                

for k in range (reps):     
    P=np.arange(nums)                 
    for i in range (nums):                
        P[i]=1                                
    fn=np.trunc(fract*nums)               
    n=0
    while n < fn:                       
        ra=np.random.randint(nums)
        if P[ra] != 0:
            P[ra]=0
            n=n+1
    n=0
    while n < 1:                        
        ra = np.random.randint(nums)
        if P[ra]==1:
            P[ra]=2
            n=1

    for j in range (numd):               
        for i in range (nums):             
            if P[i] == 2:                      
                for ii in range (num_infect):
                    ra=np.random.randint(nums)
                    if P[ra] == 1:
                        P[ra] = 2
                        remov=remov+1                         
            if np.random.rand()< recovr: 
                ra=np.random.randint(nums)
                if P[ra] == 2:
                    P[ra]=0 
        c=0
        s=0
        for i in range (nums):               
            if P[i] == 2:
                c=c+1
            if P[i] == 1:
                s=s+1
        data[j]=data[j]+c                   
        sdata[j]=sdata[j]+s                   

num_infected=remov*1.0/reps
print("Average number of students infected =",num_infected)

x=np.arange(numd)
y1=sdata/reps # Number of Susceptible Students
y2=data/reps # Number of Infected Students  
y3=nums-fn-(sdata/numd) # Number of Affected Students
plt.plot(x,y1,'g',x,y2,'r',x,y3,'k')
plt.title("A plot showing the spread of infection over \n 40 days when the fraction of recovery is 0.51")
plt.xlabel("Number of days")
plt.ylabel("Number of students")
plt.xlim(0,40)
plt.ylim(0,1000)
plt.legend(['Susceptible','Infected','Affected'])
plt.show()
# Out:
# Average number of students infected = 912.1

# %% [markdown]
# By increasing the recovery rate, the average number of infected students decreases, the number of students that are susceptible does not change however. As you increase the recovery rate the number of infected students decreases over the 40 days.<br><br> By changing the fraction of immunised students, the number of students that are susceptible change. As the fraction if immunised students increase the number of students infected decreases over the 40 days.

# %% [markdown]
# ## Question 4

# %%
nums=1000     
fract=0.01   
recovr= 0.2         
num_infect=1      
numd=40                                
reps=40                            
data= np.arange(numd)               
sdata= np.arange(numd)  
remov=0                                

for k in range (reps):     
    P=np.arange(nums)                 
    for i in range (nums):                
        P[i]=1                                
    fn=np.trunc(fract*nums)               
    n=0
    while n < fn:                       
        ra=np.random.randint(nums)
        if P[ra] != 0:
            P[ra]=0
            n=n+1
    n=0
    while n < 1:                        
        ra = np.random.randint(nums)
        if P[ra]==1:
            P[ra]=2
            n=1

    for j in range (numd):               
        for i in range (nums):             
            if P[i] == 2:                      
                for ii in range (num_infect):
                    ra=np.random.randint(nums)
                    if P[ra] == 1:
                        P[ra] = 2
                        remov=remov+1                         
            if np.random.rand()< recovr: 
                ra=np.random.randint(nums)
                if P[ra] == 2:
                    P[ra]=1 
        c=0
        s=0
        for i in range (nums):               
            if P[i] == 2:
                c=c+1
            if P[i] == 1:
                s=s+1
        data[j]=data[j]+c                   
        sdata[j]=sdata[j]+s                   

num_infected=remov*1.0/reps

x=np.arange(numd)
y1=sdata/reps # Number of Susceptible Students
y2=data/reps # Number of Infected Students 
y3=nums-fn-(sdata/numd) # Number of Affected Students 
plt.plot(x,y1,'g',x,y2,'r',x,y3,'k--')
plt.xlim(0,40)
plt.ylim(0,1000)
plt.title("Plot to show the spread of disease over 40 days")
plt.xlabel("Number of days")
plt.ylabel("Number of students")
plt.legend(['Susceptible','Infected','Affected'])
plt.show()

# %% [markdown]
# After a certain time period an equilibrium is established between the number of susceptible students and the affected & infected students. When someone recovers from the disease, they have a chance of being re-infected and thereby cannot gain immunity. This is classed as an endemic as the duration of the disease has no end date.

# %% [markdown]
# ## Self Assessment
#
# For the assignment I would give myself and 8 or 9 out of 10.<br> I feel that this is a good piece of work that I have submitted.
